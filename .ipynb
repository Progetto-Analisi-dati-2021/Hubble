# %% [markdown]
# # Grafico Mod_dist vs Redshift.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('dati supernovae 2.csv')

# %%
df
# Out:
#     # nome_SN  redshift         mod_dist    mod_dist_err     unknown
# 0      1993ah  0.028488  353,465,833,928  0.223905932998    0.128419
# 1      1993ag  0.050043  366,823,679,154  0.166828851413    0.128419
# 2       1993o  0.052926  368,176,912,545    0.1557559148    0.128419
# 3       1993b  0.070086  374,467,365,424  0.158466934433    0.128419
# 4      1992bs  0.062668  374,834,093,505  0.156099434739    0.128419
# ..        ...       ...              ...             ...         ...
# 575     D-000  1.017000  442,939,707,709  0.171046154322  148.000000
# 576     D-006  1.315000  449,713,577,744  0.187508839367    0.551672
# 577     P-009  0.821000  436,409,387,868  0.194013591972    0.551672
# 578     R-012  1.215000  452,465,209,495  0.560317445151    0.000148
# 579     Z-005  0.623000  425,145,239,973  0.241428134977    0.551672
#
# [580 rows x 5 columns]

# %%
plt.figure(figsize=(15,10),dpi = 100)
plt.plot(df['redshift'],df['mod_dist'],'o')
plt.title('Mod_dist vs redshift')
plt.xlabel('Redshift')
plt.ylabel('Mod_dist')
plt.show()
